# %% [markdown]
# # Importing Dependencies and reading the dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Built in modules
import os
import json
import pickle
import math
# Python Frameworks
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Machine Learning Frameworks
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
from sklearn.model_selection import train_test_split

# %% [markdown]
# Go to the directory where dataset is saved

# %%
os.chdir('/content/drive/MyDrive/Recipe-NER')

# %% [markdown]
# Create a pandas dataframe from the dataset

# %%
df = pd.read_csv('dataset.csv')
# Check what the dataset looks like
df.head()
# Out:
#    Example #     Word Label  Start  End
# 0          0  combine     O      0    7
# 1          0      the     O      8   11
# 2          0  paprika  B-IN     12   19
# 3          0  oregano  B-IN     20   27
# 4          0    thyme  B-IN     28   33

# %%
# Get the label distribution for non-O labels
label_dist = df['Label'].value_counts()[1:]
# Print the label distribution  
print(label_dist)
non_o_labels_count = sum(label_dist)
# Number of labels with an annotation
print("Total count of words with non-O labels: ", non_o_labels_count)
# Out:
# B-IN    5802
# B-CO    1777
# I-IN    1349
# I-TI     670
# B-TI     629
# B-ME     490
# I-ME     414
# I-CO     376
# B-TE     144
# B-AD      50
# I-AD      18
# I-TE       3
# Name: Label, dtype: int64
# Total count of words with non-O labels:  11722

# %% [markdown]
# Visualize the distribution of labels

# %%
# Create the bar chart
label_dist.plot(kind='bar')

# Add a title and axis labels
plt.title('Label Distribution')
plt.xlabel('Label')
plt.ylabel('Count')

# Show the chart
plt.show()

# %% [markdown]
# # Preprocessing and setting up variables required for the Neural Network

# %% [markdown]
# Since the labels with the value AD(Add-ons) are very small compared to the other labels it might be best to ignore them for this model.

# %%
ignore = ['B-AD', 'I-AD']
df['Label'] = df['Label'].replace(ignore, 'O')
label_dist = df['Label'].value_counts()[1:]
print(label_dist)
non_o_labels_count = sum(label_dist)
print("Updated total count of words with non-O labels after ignoring certain tags: ", non_o_labels_count)
# Out:
# B-IN    5802
# B-CO    1777
# I-IN    1349
# I-TI     670
# B-TI     629
# B-ME     490
# I-ME     414
# I-CO     376
# B-TE     144
# I-TE       3
# Name: Label, dtype: int64
# Updated total count of words with non-O labels after ignoring certain tags:  11654

# %% [markdown]
# Number of Unique Words

# %%
words = list(set(list(df['Word'].values)))
n_words = len(words)
n_words
# Out:
# 2115

# %%
tags = list(set(df["Label"].values))

# Save the list to a file for inference
with open("tags", "wb") as fp:  
  pickle.dump(tags, fp)
# Load the file to make sure it was saved
with open("tags", "rb") as fp:   
    tags = pickle.load(fp)

# %% [markdown]
# Number of tags

# %%
n_tags = len(tags)
n_tags
# Out:
# 11

# %% [markdown]
# The class object is used to get the datapoints grouped into a list of list containing tupples. The data is grouped by example number, then all the words and corresponding labels are placed in a tupple.

# %%
class ExampleGetter(object):
    def __init__(self, data):
        self.data = data
        agg_func = lambda s: [(w, t) for w, t in zip(s["Word"].values.tolist(), s["Label"].values.tolist())]
        self.grouped = self.data.groupby("Example #").apply(agg_func)
        self.examples = [s for s in self.grouped]

# %%
getter = ExampleGetter(df)
examples = getter.examples
examples[0]
# Out:
# [('combine', 'O'),
#  ('the', 'O'),
#  ('paprika', 'B-IN'),
#  ('oregano', 'B-IN'),
#  ('thyme', 'B-IN'),
#  ('garlic', 'B-IN'),
#  ('powder', 'I-IN'),
#  ('onion', 'B-IN'),
#  ('powder', 'I-IN'),
#  ('salt', 'B-IN'),
#  ('and', 'O'),
#  ('pepper', 'B-IN'),
#  ('in', 'O'),
#  ('a', 'O'),
#  ('small', 'O'),
#  ('bowl', 'B-CO'),
#  ('coat', 'O'),
#  ('both', 'O'),
#  ('sides', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('chicken', 'B-IN'),
#  ('thighs', 'I-IN'),
#  ('in', 'O'),
#  ('the', 'O'),
#  ('seasoning', 'O'),
#  ('mix', 'O'),
#  ('add', 'O'),
#  ('1', 'B-ME'),
#  ('Tbsp', 'I-ME'),
#  ('cooking', 'B-IN'),
#  ('oil', 'I-IN'),
#  ('to', 'O'),
#  ('a', 'O'),
#  ('deep', 'O'),
#  ('skillet', 'B-CO'),
#  ('and', 'O'),
#  ('heat', 'O'),
#  ('over', 'O'),
#  ('medium', 'O'),
#  ('once', 'O'),
#  ('hot', 'O'),
#  ('swirl', 'O'),
#  ('to', 'O'),
#  ('coat', 'O'),
#  ('the', 'O'),
#  ('surface', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('skillet', 'B-CO'),
#  ('then', 'O'),
#  ('add', 'O'),
#  ('the', 'O'),
#  ('chicken', 'B-IN'),
#  ('thighs', 'I-IN'),
#  ('cook', 'O'),
#  ('the', 'O'),
#  ('thighs', 'O'),
#  ('for', 'O'),
#  ('a', 'O'),
#  ('few', 'B-TI'),
#  ('minutes', 'I-TI'),
#  ('on', 'O'),
#  ('each', 'O'),
#  ('side', 'O'),
#  ('or', 'O'),
#  ('until', 'O'),
#  ('well', 'O'),
#  ('browned', 'O'),
#  ('the', 'O'),
#  ('chicken', 'B-IN'),
#  ('does', 'O'),
#  ('not', 'O'),
#  ('need', 'O'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('cooked', 'O'),
#  ('through', 'O'),
#  ('at', 'O'),
#  ('this', 'O'),
#  ('point', 'O'),
#  ('remove', 'O'),
#  ('the', 'O'),
#  ('browned', 'O'),
#  ('chicken', 'B-IN'),
#  ('to', 'O'),
#  ('a', 'O'),
#  ('clean', 'O'),
#  ('plate', 'B-CO'),
#  ('reduce', 'O'),
#  ('the', 'O'),
#  ('heat', 'O'),
#  ('to', 'O'),
#  ('medium-low', 'O'),
#  ('add', 'O'),
#  ('an', 'O'),
#  ('additional', 'O'),
#  ('1', 'B-ME'),
#  ('Tbsp', 'I-ME'),
#  ('cooking', 'B-IN'),
#  ('oil', 'I-IN'),
#  ('to', 'O'),
#  ('the', 'O'),
#  ('skillet', 'B-CO'),
#  ('then', 'O'),
#  ('add', 'O'),
#  ('the', 'O'),
#  ('diced', 'O'),
#  ('onion', 'B-IN'),
#  ('sauté', 'O'),
#  ('the', 'O'),
#  ('onion', 'B-IN'),
#  ('for', 'O'),
#  ('about', 'O'),
#  ('5', 'B-TI'),
#  ('minutes', 'I-TI'),
#  ('or', 'O'),
#  ('until', 'O'),
#  ('softened', 'O'),
#  ('allow', 'O'),
#  ('the', 'O'),
#  ('moisture', 'O'),
#  ('from', 'O'),
#  ('the', 'O'),
#  ('onion', 'B-IN'),
#  ('to', 'O'),
#  ('dissolve', 'O'),
#  ('the', 'O'),
#  ('browned', 'O'),
#  ('bits', 'O'),
#  ('from', 'O'),
#  ('the', 'O'),
#  ('skillet', 'B-CO'),
#  ('as', 'O'),
#  ('you', 'O'),
#  ('stir', 'O'),
#  ('add', 'O'),
#  ('the', 'O'),
#  ('uncooked', 'O'),
#  ('rice', 'B-IN'),
#  ('to', 'O'),
#  ('the', 'O'),
#  ('skillet', 'B-CO'),
#  ('and', 'O'),
#  ('continue', 'O'),
#  ('to', 'O'),
#  ('sauté', 'O'),
#  ('for', 'O'),
#  ('1-2', 'B-TI'),
#  ('minutes', 'I-TI'),
#  ('more', 'O'),
#  ('to', 'O'),
#  ('toast', 'O'),
#  ('the', 'O'),
#  ('rice', 'B-IN'),
#  ('add', 'O'),
#  ('the', 'O'),
#  ('vegetable', 'B-IN'),
#  ('broth', 'I-IN'),
#  ('to', 'O'),
#  ('the', 'O'),
#  ('skillet', 'B-CO'),
#  ('and', 'O'),
#  ('briefly', 'O'),
#  ('stir', 'O'),
#  ('to', 'O'),
#  ('dissolve', 'O'),
#  ('any', 'O'),
#  ('remaining', 'O'),
#  ('brown', 'O'),
#  ('bits', 'O'),
#  ('from', 'O'),
#  ('the', 'O'),
#  ('bottom', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('skillet', 'B-CO'),
#  ('return', 'O'),
#  ('the', 'O'),
#  ('chicken', 'B-IN'),
#  ('to', 'O'),
#  ('the', 'O'),
#  ('skillet', 'B-CO'),
#  ('setting', 'O'),
#  ('it', 'O'),
#  ('on', 'O'),
#  ('top', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('rice', 'B-IN'),
#  ('place', 'O'),
#  ('a', 'O'),
#  ('lid', 'O'),
#  ('on', 'O'),
#  ('the', 'O'),
#  ('skillet', 'B-CO'),
#  ('turn', 'O'),
#  ('the', 'O'),
#  ('heat', 'O'),
#  ('up', 'O'),
#  ('to', 'O'),
#  ('medium-high', 'O'),
#  ('and', 'O'),
#  ('allow', 'O'),
#  ('the', 'O'),
#  ('broth', 'B-IN'),
#  ('to', 'O'),
#  ('come', 'O'),
#  ('up', 'O'),
#  ('to', 'O'),
#  ('a', 'O'),
#  ('full', 'O'),
#  ('boil', 'O'),
#  ('once', 'O'),
#  ('boiling', 'O'),
#  ('turn', 'O'),
#  ('the', 'O'),
#  ('heat', 'O'),
#  ('down', 'O'),
#  ('to', 'O'),
#  ('low', 'O'),
#  ('and', 'O'),
#  ('let', 'O'),
#  ('the', 'O'),
#  ('chicken', 'B-IN'),
#  ('and', 'O'),
#  ('rice', 'B-IN'),
#  ('continue', 'O'),
#  ('to', 'O'),
#  ('simmer', 'O'),
#  ('over', 'O'),
#  ('low', 'O'),
#  ('without', 'O'),
#  ('lifting', 'O'),
#  ('the', 'O'),
#  ('lid', 'O'),
#  ('or', 'O'),
#  ('stirring', 'B-CO'),
#  ('for', 'O'),
#  ('20', 'B-TI'),
#  ('minutes', 'I-TI'),
#  ('after', 'O'),
#  ('20', 'B-TI'),
#  ('minutes', 'I-TI'),
#  ('turn', 'O'),
#  ('off', 'O'),
#  ('the', 'O'),
#  ('heat', 'O'),
#  ('and', 'O'),
#  ('let', 'O'),
#  ('it', 'O'),
#  ('rest', 'O'),
#  ('without', 'O'),
#  ('lifting', 'O'),
#  ('the', 'O'),
#  ('lid', 'O'),
#  ('for', 'O'),
#  ('an', 'O'),
#  ('additional', 'O'),
#  ('5', 'B-TI'),
#  ('minutes', 'I-TI'),
#  ('finally', 'O'),
#  ('remove', 'O'),
#  ('the', 'O'),
#  ('lid', 'O'),
#  ('and', 'O'),
#  ('fluff', 'O'),
#  ('the', 'O'),
#  ('rice', 'B-IN'),
#  ('around', 'O'),
#  ('the', 'O'),
#  ('chicken', 'B-IN'),
#  ('garnish', 'O'),
#  ('with', 'O'),
#  ('chopped', 'O'),
#  ('parsley', 'O'),
#  ('if', 'O'),
#  ('desired', 'O'),
#  ('then', 'O'),
#  ('serve', 'O'),
#  ('and', 'O'),
#  ('enjoy', 'O')]

# %%
print("The number of examples in the training set:", len(examples))
max_len = max([len(examples[i]) for i in range(len(examples))])
print("The longest sentence has {} words".format(max_len))
# Out:
# The number of examples in the training set: 300
# The longest sentence has 888 words

# %%
# Create the Histogram Chart
plt.hist([len(example) for example in examples], bins= 20)


# Add a title and axis labels
plt.title('Sentence Lengths Distribution')
plt.ylabel('Count')
plt.xlabel('Length')

# Show the chart
plt.show()

# %%
def roundup(x):
  # Rounds up to the nearest hundreds
  return int(math.ceil(x / 100.0)) * 100

# %%
max_len = roundup(max_len)
print(max_len)
# Out:
# 900

# %% [markdown]
# Categorical data is converted to numerical data to make it easier for the neural network to learn

# %%
word2idx = {w: i + 1 for i, w in enumerate(words)}
# Save the dictionary to a json file for inference
with open("word2idx.json", "w") as outfile:
  json.dump(word2idx, outfile)
# Load the file to make sure it was saved
with open('word2idx.json', 'r') as fcc_file:
    word2idx = json.load(fcc_file)

# %%
tag2idx = {t: i for i, t in enumerate(tags)}
# Save the dictionary to a json file for inference
with open("tag2idx.json", "w") as outfile:
  json.dump(tag2idx, outfile)
# Load the file to make sure it was saved
with open('tag2idx.json', 'r') as fcc_file:
    tag2idx = json.load(fcc_file)

# %% [markdown]
# Padding is done to make the data have a constant length, since neural networks require the same input sizes

# %%
X = [[word2idx[w[0]] for w in s] for s in examples]
X = pad_sequences(maxlen=max_len, sequences=X, padding="post", value=0)

# %%
y = [[tag2idx[w[1]] for w in s] for s in examples]
y = pad_sequences(maxlen=max_len, sequences=y, padding="post", value=tag2idx["O"])

# %% [markdown]
# The function to_categorical was used on y, since the neural network to be used is Categorical Crossentropy

# %%
y = [to_categorical(i, num_classes=n_tags) for i in y]

# %% [markdown]
# Split the dataset into training and testing, with 15% of the dataset being used for testing

# %%
X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.15)

# %% [markdown]
# # Machine Learning

# %% [markdown]
# Model Architechture used for the Deep Learning Model

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Embedding(n_words+1, 2048, input_length=max_len),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(units=512, activation='tanh', return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(units=256, activation='tanh', return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(units=128, activation='tanh', return_sequences=True)),
    tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(256)),
    tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(128)),
    tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(64)),
    tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(32)),
    tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(n_tags, activation='softmax'))
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 900, 2048)         4333568
#
#  bidirectional (Bidirectiona  (None, 900, 1024)        10489856
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 900, 512)         2623488
#  nal)
#
#  bidirectional_2 (Bidirectio  (None, 900, 256)         656384
#  nal)
#
#  time_distributed (TimeDistr  (None, 900, 256)         65792
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 900, 128)         32896
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 900, 64)          8256
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 900, 32)          2080
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 900, 11)          363
#  tributed)
#
# =================================================================
# Total params: 18,212,683
# Trainable params: 18,212,683
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the neural network using gpu. 15% of the training set will be set aside to be used for validation.

# %%
with tf.device('/GPU:0'):
  history = model.fit(X_tr, np.array(y_tr), batch_size=16, epochs=20, validation_split=0.15, verbose=1)
# Out:
# Epoch 1/20
# 14/14 [==============================] - 29s 782ms/step - loss: 0.4803 - accuracy: 0.8836 - val_loss: 0.1837 - val_accuracy: 0.9589
# Epoch 2/20
# 14/14 [==============================] - 8s 571ms/step - loss: 0.1800 - accuracy: 0.9559 - val_loss: 0.1581 - val_accuracy: 0.9591
# Epoch 3/20
# 14/14 [==============================] - 8s 576ms/step - loss: 0.1611 - accuracy: 0.9561 - val_loss: 0.1463 - val_accuracy: 0.9589
# Epoch 4/20
# 14/14 [==============================] - 8s 582ms/step - loss: 0.1488 - accuracy: 0.9567 - val_loss: 0.1358 - val_accuracy: 0.9607
# Epoch 5/20
# 14/14 [==============================] - 8s 604ms/step - loss: 0.1355 - accuracy: 0.9583 - val_loss: 0.1231 - val_accuracy: 0.9617
# Epoch 6/20
# 14/14 [==============================] - 8s 601ms/step - loss: 0.1185 - accuracy: 0.9609 - val_loss: 0.1053 - val_accuracy: 0.9642
# Epoch 7/20
# 14/14 [==============================] - 9s 614ms/step - loss: 0.0907 - accuracy: 0.9680 - val_loss: 0.0798 - val_accuracy: 0.9742
# Epoch 8/20
# 14/14 [==============================] - 8s 599ms/step - loss: 0.0607 - accuracy: 0.9807 - val_loss: 0.0602 - val_accuracy: 0.9817
# Epoch 9/20
# 14/14 [==============================] - 8s 597ms/step - loss: 0.0456 - accuracy: 0.9855 - val_loss: 0.0508 - val_accuracy: 0.9863
# Epoch 10/20
# 14/14 [==============================] - 8s 591ms/step - loss: 0.0346 - accuracy: 0.9896 - val_loss: 0.0478 - val_accuracy: 0.9873
# Epoch 11/20
# 14/14 [==============================] - 8s 590ms/step - loss: 0.0257 - accuracy: 0.9926 - val_loss: 0.0432 - val_accuracy: 0.9888
# Epoch 12/20
# 14/14 [==============================] - 8s 589ms/step - loss: 0.0201 - accuracy: 0.9940 - val_loss: 0.0425 - val_accuracy: 0.9894
# Epoch 13/20
# 14/14 [==============================] - 9s 614ms/step - loss: 0.0167 - accuracy: 0.9949 - val_loss: 0.0432 - val_accuracy: 0.9897
# Epoch 14/20
# 14/14 [==============================] - 8s 587ms/step - loss: 0.0136 - accuracy: 0.9960 - val_loss: 0.0432 - val_accuracy: 0.9901
# Epoch 15/20
# 14/14 [==============================] - 8s 590ms/step - loss: 0.0111 - accuracy: 0.9966 - val_loss: 0.0479 - val_accuracy: 0.9901
# Epoch 16/20
# 14/14 [==============================] - 8s 592ms/step - loss: 0.0094 - accuracy: 0.9972 - val_loss: 0.0478 - val_accuracy: 0.9907
# Epoch 17/20
# 14/14 [==============================] - 8s 609ms/step - loss: 0.0072 - accuracy: 0.9979 - val_loss: 0.0523 - val_accuracy: 0.9900
# Epoch 18/20
# 14/14 [==============================] - 9s 618ms/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.0562 - val_accuracy: 0.9889
# Epoch 19/20
# 14/14 [==============================] - 8s 595ms/step - loss: 0.0062 - accuracy: 0.9981 - val_loss: 0.0554 - val_accuracy: 0.9901
# Epoch 20/20
# 14/14 [==============================] - 8s 594ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.0562 - val_accuracy: 0.9906

# %% [markdown]
# Save the model for Inference

# %%
model.save('ner_model_20e.h5')

# %%
# Create the Histogram Chart
hist = pd.DataFrame(history.history)
plt.plot(hist["accuracy"])
plt.plot(hist["val_accuracy"])
plt.style.use("ggplot")

# Add a title and axis labels
plt.title('Sentence Lengths Distribution')
plt.ylabel('Value')
plt.xlabel('Epoch')



# Show the chart
plt.figure(figsize=(24, 24))

# %% [markdown]
# # Inference and Model Evaluation

# %% [markdown]
# Load the trained Model

# %%
loaded_model = tf.keras.models.load_model('ner_model_20e.h5')

# %% [markdown]
# co stands for cookware
#
# te stands for temperature
#
# in stands for ingredient
#
# me stands for measurement
#
# ti stands for time
#
# O stands for no label

# %%
truth_table = ["true_positive", "false_positive", "false_negative"]
# Create the confusion matrix to be used to compute evaluation metrics
confusion_matrix_dict = {tag_idx:{truth_table_idx:0 for truth_table_idx in truth_table} for tag_idx in tag2idx.keys()}

for i in range(len(X_te)):
  # p stands for the probabilities predicted by the model on the input text
  p = loaded_model.predict(np.array([X_te[i]]))
  # Returns an array of the classes with the max probabilities of the prediction
  p = np.argmax(p, axis=-1)
  # Returns the labels on the words that were manually labelled
  true = np.argmax(y_te[i], -1)
  print("{}||{}||{}".format("Word", "True", "Pred"))
  print(30 * "=")
  for w, t, pred in zip(X_te[i], true, p[0]):
      if w != 0:
          print("{:15}: {:5} {}".format(words[w-1], tags[t], tags[pred]))
          if tags[pred] ==  tags[t]:
            # Count of true positive increases when the prediction of the model is the same as the tag that was manually labelled 
            confusion_matrix_dict[tags[pred]]["true_positive"] += 1
          elif tags[pred] != tags[t]:
            # Count of false positive for the predicted tag increases
            confusion_matrix_dict[tags[pred]]["false_positive"] += 1
            # Count of false negative for the ground truth tag increases
            confusion_matrix_dict[tags[t]]["false_negative"] += 1
# Out:
# Streaming output truncated to the last 5000 lines.
# the            : O     O
# consistency    : O     O
# of             : O     O
# heavy          : B-IN  B-IN
# cream          : I-IN  I-IN
# or             : O     O
# gravy          : B-IN  O
# turn           : O     O
# the            : O     O
# burner         : B-CO  B-CO
# off            : O     O
# season         : O     O
# the            : O     O
# white          : B-IN  O
# sauce          : I-IN  O
# with           : O     O
# the            : O     O
# salt           : B-IN  B-IN
# and            : O     O
# hot            : B-IN  O
# sauce          : I-IN  O
# begin          : O     O
# to             : O     O
# add            : O     O
# the            : O     O
# shredded       : B-IN  O
# cheddar        : I-IN  B-IN
# one            : O     O
# handful        : O     O
# at             : O     O
# a              : O     O
# time           : O     O
# whisking       : O     O
# it             : O     O
# in             : O     O
# until          : O     O
# completely     : O     O
# melted         : O     O
# before         : O     O
# adding         : O     O
# more           : O     O
# continue       : O     O
# until          : O     O
# all            : O     O
# of             : O     O
# the            : O     O
# cheese         : B-IN  B-IN
# has            : O     O
# been           : O     O
# melted         : O     O
# into           : O     O
# the            : O     O
# sauce          : O     O
# if             : O     O
# the            : O     O
# sauce          : O     O
# becomes        : O     O
# too            : O     O
# cold           : O     O
# to             : O     O
# melt           : O     O
# the            : O     O
# cheese         : B-IN  O
# place          : O     O
# it             : O     O
# back           : O     O
# over           : O     O
# low            : O     O
# heat           : O     O
# only           : O     O
# briefly        : O     O
# to             : O     O
# continue       : O     O
# melting        : O     O
# the            : O     O
# cheese         : B-IN  B-IN
# overheating    : O     O
# the            : O     O
# sauce          : O     O
# can            : O     O
# cause          : O     O
# it             : O     O
# to             : O     O
# break          : O     O
# and            : O     O
# become         : O     O
# grainy         : O     O
# add            : O     O
# the            : O     O
# cooked         : O     O
# and            : O     O
# drained        : O     O
# pasta          : B-IN  B-IN
# to             : O     O
# the            : O     O
# pot            : B-CO  B-CO
# with           : O     O
# the            : O     O
# cheese         : B-IN  B-IN
# sauce          : O     O
# and            : O     O
# stir           : O     O
# to             : O     O
# combine        : O     O
# serve          : O     O
# the            : O     O
# mac            : O     O
# and            : O     O
# cheese         : O     B-IN
# hot            : O     O
# and            : O     O
# enjoy          : O     O
# 1/1 [==============================] - 0s 205ms/step
# Word||True||Pred
# ==============================
# in             : O     O
# a              : O     O
# small          : O     O
# bowl           : B-CO  B-CO
# combine        : O     O
# the            : O     O
# olive          : B-IN  B-IN
# oil            : I-IN  I-IN
# red            : B-IN  B-IN
# wine           : I-IN  I-IN
# vinegar        : B-IN  B-IN
# minced         : O     O
# garlic         : B-IN  B-IN
# ½              : B-ME  B-ME
# tsp            : I-ME  I-ME
# dried          : O     O
# basil          : B-IN  B-IN
# salt           : B-IN  B-IN
# and            : O     O
# pepper         : B-IN  B-IN
# use            : O     O
# a              : O     O
# sharp          : O     O
# knife          : B-CO  B-CO
# to             : O     O
# fillet         : O     O
# the            : O     O
# chicken        : B-IN  B-IN
# breasts        : I-IN  I-IN
# into           : O     O
# two            : O     O
# thinner        : O     O
# pieces         : O     O
# each           : O     O
# place          : O     O
# the            : O     O
# chicken        : B-IN  B-IN
# breast         : I-IN  I-IN
# pieces         : O     O
# in             : O     O
# a              : O     O
# shallow        : O     O
# dish           : B-CO  B-CO
# and            : O     O
# pour           : O     O
# the            : O     O
# marinade       : B-IN  O
# over           : O     O
# top            : O     O
# flip           : O     O
# the            : O     O
# chicken        : B-IN  B-IN
# a              : O     O
# couple         : O     O
# of             : O     O
# times          : O     O
# to             : O     O
# make           : O     O
# sure           : O     O
# all            : O     O
# surfaces       : O     O
# are            : O     O
# coated         : O     O
# marinate       : O     O
# the            : O     O
# chicken        : B-IN  B-IN
# for            : O     O
# 30             : B-TI  B-TI
# minutes        : I-TI  I-TI
# or             : O     O
# up             : O     O
# to             : O     O
# one            : B-TI  O
# day            : I-TI  O
# refrigerated   : O     O
# flipping       : O     O
# once           : O     O
# or             : O     O
# twice          : O     O
# throughout     : O     O
# heat           : O     O
# a              : O     O
# large          : O     O
# skillet        : B-CO  B-CO
# over           : O     O
# medium         : O     O
# once           : O     O
# the            : O     O
# pan            : B-CO  B-CO
# is             : O     O
# hot            : O     O
# transfer       : O     O
# the            : O     O
# chicken        : B-IN  B-IN
# pieces         : O     O
# to             : O     O
# the            : O     O
# skillet        : B-CO  B-CO
# there          : O     O
# should         : O     O
# be             : O     O
# enough         : O     O
# oil            : B-IN  B-IN
# from           : O     O
# the            : O     O
# marinade       : B-IN  O
# to             : O     O
# prevent        : O     O
# sticking       : O     O
# cook           : O     O
# the            : O     O
# chicken        : B-IN  B-IN
# for            : O     O
# about          : O     O
# five           : B-TI  B-TI
# minutes        : I-TI  I-TI
# on             : O     O
# each           : O     O
# side           : O     O
# or             : O     O
# until          : O     O
# golden         : O     O
# brown          : O     O
# and            : O     O
# cooked         : O     O
# through        : O     O
# then           : O     O
# remove         : O     O
# it             : O     O
# to             : O     O
# a              : O     O
# clean          : O     O
# plate          : B-CO  B-CO
# add            : O     O
# the            : O     O
# tomato         : B-IN  B-IN
# paste          : I-IN  I-IN
# chicken        : B-IN  B-IN
# broth          : I-IN  I-IN
# the            : O     O
# remaining      : O     O
# ½              : B-ME  B-ME
# tsp            : I-ME  I-ME
# dried          : O     O
# basil          : B-IN  B-IN
# and            : O     O
# sugar          : B-IN  B-IN
# to             : O     O
# the            : O     O
# skillet        : B-CO  B-CO
# use            : O     O
# a              : O     O
# whisk          : B-CO  O
# to             : O     O
# combine        : O     O
# the            : O     O
# ingredients    : O     O
# and            : O     O
# dissolve       : O     O
# any            : O     O
# browned        : O     O
# bits           : O     O
# off            : O     O
# the            : O     O
# bottom         : O     O
# of             : O     O
# the            : O     O
# skillet        : B-CO  B-CO
# let            : O     O
# the            : O     O
# sauce          : O     O
# simmer         : O     O
# over           : O     O
# medium-low     : O     O
# heat           : O     O
# for            : O     O
# about          : O     O
# five           : B-TI  B-TI
# minutes        : I-TI  I-TI
# or             : O     O
# until          : O     O
# slightly       : O     O
# thickened      : O     O
# return         : O     O
# the            : O     O
# chicken        : B-IN  B-IN
# to             : O     O
# the            : O     O
# skillet        : B-CO  B-CO
# and            : O     O
# spoon          : B-CO  B-CO
# the            : O     O
# sauce          : O     O
# over           : O     O
# top            : O     O
# serve          : O     O
# and            : O     O
# enjoy          : O     O
# 1/1 [==============================] - 0s 201ms/step
# Word||True||Pred
# ==============================
# preheat        : O     O
# the            : O     O
# oven           : B-CO  B-CO
# to             : O     O
# 400ºf          : B-TE  B-TE
# place          : O     O
# the            : O     O
# chicken        : B-IN  B-IN
# wings          : I-IN  I-IN
# in             : O     O
# a              : O     O
# glass          : O     B-CO
# or             : O     O
# ceramic        : O     O
# baking         : B-CO  B-CO
# dish           : I-CO  I-CO
# so             : O     O
# that           : O     O
# theyre         : O     O
# in             : O     O
# a              : O     O
# single         : O     O
# layer          : O     O
# drizzle        : O     O
# the            : O     O
# cooking        : B-IN  O
# oil            : I-IN  I-IN
# over           : O     O
# top            : O     O
# then           : O     O
# toss           : O     O
# the            : O     O
# wings          : B-IN  O
# to             : O     O
# coat           : O     O
# in             : O     O
# the            : O     O
# oil            : B-IN  B-IN
# transfer       : O     O
# the            : O     O
# wings          : B-IN  B-CO
# to             : O     O
# the            : O     O
# oven           : B-CO  B-CO
# and            : O     O
# bake           : O     O
# for            : O     O
# 15             : B-TI  B-TI
# minutes        : I-TI  I-TI
# while          : O     O
# the            : O     O
# wings          : B-IN  O
# are            : O     O
# baking         : O     O
# prepare        : O     O
# the            : O     O
# sticky         : O     O
# ginger         : B-IN  B-IN
# sauce          : O     O
# combine        : O     O
# the            : O     O
# honey          : B-IN  B-IN
# soy            : B-IN  B-IN
# sauce          : I-IN  I-IN
# chili          : B-IN  B-IN
# garlic         : I-IN  I-IN
# sauce          : I-IN  I-IN
# toasted        : O     O
# sesame         : B-IN  B-IN
# oil            : I-IN  I-IN
# rice           : B-IN  B-IN
# vinegar        : I-IN  I-IN
# minced         : O     O
# garlic         : B-IN  B-IN
# and            : O     O
# grated         : O     O
# ginger         : B-IN  B-IN
# in             : O     O
# a              : O     O
# bowl           : B-CO  B-CO
# after          : O     O
# the            : O     O
# wings          : B-IN  O
# have           : O     O
# baked          : O     O
# for            : O     O
# 15             : B-TI  B-TI
# minutes        : I-TI  I-TI
# pour           : O     O
# the            : O     O
# sauce          : O     O
# over           : O     O
# the            : O     O
# wings          : B-IN  O
# then           : O     O
# toss           : O     O
# to             : O     O
# coat           : O     O
# return         : O     O
# the            : O     O
# wings          : B-IN  B-CO
# to             : O     O
# the            : O     O
# oven           : B-CO  B-CO
# and            : O     O
# bake           : O     O
# for            : O     O
# an             : O     O
# additional     : O     O
# 45             : B-TI  B-TI
# minutes        : I-TI  I-TI
# stirring       : O     O
# every          : O     O
# 15             : B-TI  B-TI
# minutes        : I-TI  I-TI
# or             : O     O
# until          : O     O
# the            : O     O
# sauce          : O     O
# has            : O     O
# reduced        : O     O
# into           : O     O
# a              : O     O
# sticky         : O     O
# glaze          : O     O
# and            : O     O
# deepened       : O     O
# in             : O     O
# color          : O     O
# baking         : O     O
# time           : O     O
# may            : O     O
# vary           : O     O
# slightly       : O     O
# so             : O     O
# keep           : O     O
# an             : O     O
# eye            : O     O
# on             : O     O
# the            : O     O
# sauce          : O     O
# toward         : O     O
# the            : O     O
# end            : O     O
# of             : O     O
# the            : O     O
# baking         : O     O
# time           : O     O
# top            : O     O
# with           : O     O
# sliced         : O     O
# green          : B-IN  B-IN
# onions         : I-IN  I-IN
# and            : O     O
# serve          : O     O
# 1/1 [==============================] - 0s 192ms/step
# Word||True||Pred
# ==============================
# add            : O     O
# the            : O     O
# rolled         : O     O
# oats           : B-IN  B-IN
# uncooked       : O     O
# pumpkin        : B-IN  B-IN
# pie            : I-IN  I-IN
# spice          : B-IN  I-IN
# salt           : B-IN  I-IN
# and            : O     O
# chopped        : O     O
# pecans         : B-IN  B-IN
# to             : O     O
# a              : O     O
# jar            : B-CO  B-CO
# or             : O     O
# other          : O     O
# resealable     : B-CO  B-CO
# container      : I-CO  B-CO
# top            : O     O
# with           : O     O
# the            : O     O
# pumpkin        : B-IN  B-IN
# purée          : I-IN  I-IN
# brown          : B-IN  B-IN
# sugar          : I-IN  I-IN
# and            : O     O
# milk           : B-IN  B-IN
# close          : O     O
# the            : O     O
# container      : B-CO  B-CO
# and            : O     O
# refrigerate    : O     O
# overnight      : B-TI  B-TI
# or             : O     O
# up             : O     O
# to             : O     O
# five           : B-TI  B-TI
# days           : I-TI  I-TI
# before         : O     O
# eating         : O     O
# stir           : O     O
# the            : O     O
# contents       : O     O
# of             : O     O
# the            : O     O
# jar            : B-CO  B-CO
# until          : O     O
# evenly         : O     O
# combined       : O     O
# enjoy          : O     O
# cold           : O     O
# or             : O     O
# microwave      : B-CO  B-CO
# until          : O     O
# warmed         : O     O
# through        : O     O
# 1/1 [==============================] - 0s 166ms/step
# Word||True||Pred
# ==============================
# make           : O     O
# the            : O     O
# vinaigrette    : B-IN  O
# first          : O     O
# combine        : O     O
# the            : O     O
# olive          : B-IN  B-IN
# oil            : I-IN  I-IN
# lemon          : B-IN  B-IN
# juice          : O     O
# red            : B-IN  B-IN
# wine           : I-IN  I-IN
# vinegar        : B-IN  B-IN
# dijon          : B-IN  B-IN
# garlic         : B-IN  B-IN
# salt           : B-IN  B-IN
# and            : O     O
# pepper         : B-IN  B-IN
# in             : O     O
# a              : O     O
# bowl           : B-CO  B-CO
# whisk          : O     O
# the            : O     O
# ingredients    : O     O
# together       : O     O
# until          : O     O
# smooth         : O     O
# then           : O     O
# set            : O     O
# the            : O     O
# dressing       : O     O
# aside          : O     O
# wash           : O     O
# the            : O     O
# potatoes       : B-IN  B-IN
# and            : O     O
# slice          : O     O
# them           : O     O
# in             : O     O
# half           : O     O
# or             : O     O
# into           : O     O
# 1-inch         : B-ME  B-ME
# pieces         : O     O
# place          : O     O
# the            : O     O
# potatoes       : B-IN  B-IN
# in             : O     O
# a              : O     O
# pot            : B-CO  B-CO
# cover          : O     O
# with           : O     O
# water          : B-IN  B-IN
# and            : O     O
# add            : O     O
# 1              : B-ME  B-ME
# tsp            : I-ME  I-ME
# salt           : B-IN  B-IN
# bring          : O     O
# the            : O     O
# pot            : B-CO  B-CO
# of             : O     O
# water          : B-IN  B-IN
# to             : O     O
# a              : O     O
# boil           : O     O
# over           : O     O
# medium-high    : O     O
# heat           : O     O
# boil           : O     O
# the            : O     O
# potatoes       : B-IN  B-IN
# until          : O     O
# tender         : O     O
# 8-10           : B-ME  B-TI
# minutes        : I-ME  I-TI
# drain          : O     O
# the            : O     O
# potatoes       : B-IN  B-IN
# in             : O     O
# a              : O     O
# colander       : B-CO  B-CO
# and            : O     O
# let            : O     O
# them           : O     O
# cool           : O     O
# until          : O     O
# they           : O     O
# are            : O     O
# still          : O     O
# warm           : O     O
# bu             : O     O
# no             : O     O
# longer         : O     O
# steaming       : O     O
# while          : O     O
# the            : O     O
# potatoes       : B-IN  B-IN
# are            : O     O
# cooling        : O     O
# chop           : O     O
# the            : O     O
# parsley        : B-IN  B-IN
# basil          : B-IN  B-IN
# and            : O     O
# green          : B-IN  B-IN
# onion          : I-IN  I-IN
# place          : O     O
# the            : O     O
# drained        : O     O
# and            : O     O
# slightly       : O     O
# cooled         : O     O
# potatoes       : B-IN  B-IN
# in             : O     O
# a              : O     O
# bowl           : B-CO  B-CO
# pour           : O     O
# the            : O     O
# vinaigrette    : B-IN  O
# over           : O     O
# top            : O     O
# and            : O     O
# stir           : O     O
# to             : O     O
# coat           : O     O
# let            : O     O
# the            : O     O
# potatoes       : B-IN  O
# sit            : O     O
# for            : O     O
# about          : O     O
# five           : B-TI  B-TI
# minutes        : I-TI  I-TI
# stirring       : O     O
# occasionally   : O     O
# so             : O     O
# they           : O     O
# can            : O     O
# absorb         : O     O
# some           : O     O
# of             : O     O
# the            : O     O
# dressing       : O     O
# finally        : O     O
# add            : O     O
# the            : O     O
# chopped        : O     O
# herbs          : B-IN  O
# and            : O     O
# stir           : O     O
# to             : O     O
# combine        : O     O
# taste          : O     O
# and            : O     O
# adjust         : O     O
# the            : O     O
# salt           : B-IN  B-IN
# and            : O     O
# pepper         : B-IN  B-IN
# to             : O     O
# your           : O     O
# liking         : O     O
# serve          : O     O
# warm           : O     O
# or             : O     O
# refrigerate    : O     O
# until          : O     O
# ready          : O     O
# to             : O     O
# serve          : O     O
# 1/1 [==============================] - 0s 194ms/step
# Word||True||Pred
# ==============================
# preheat        : O     O
# the            : O     O
# oven           : B-CO  B-CO
# to             : O     O
# 400ºf          : B-TE  B-TE
# remove         : O     O
# any            : O     O
# loose          : O     O
# outer          : O     O
# pieces         : O     O
# of             : O     O
# papery         : O     O
# skin           : O     O
# from           : O     O
# the            : O     O
# heads          : O     O
# of             : O     O
# garlic         : B-IN  B-IN
# slice          : O     O
# off            : O     O
# the            : O     O
# top            : O     O
# ⅓              : O     O
# of             : O     O
# each           : O     O
# head           : O     O
# to             : O     O
# expose         : O     O
# the            : O     O
# cloves         : O     B-CO
# inside         : O     O
# save           : O     O
# the            : O     O
# pieces         : O     O
# of             : O     O
# garlic         : B-IN  B-IN
# cloves         : O     O
# that           : O     O
# have           : O     O
# been           : O     O
# cut            : O     O
# off            : O     O
# to             : O     O
# use            : O     O
# in             : O     O
# other          : O     O
# recipes        : O     O
# place          : O     O
# the            : O     O
# garlic         : B-IN  O
# in             : O     O
# a              : O     O
# baking         : B-CO  B-CO
# dish           : I-CO  I-CO
# drizzle        : O     O
# olive          : B-IN  B-IN
# oil            : I-IN  I-IN
# over           : O     O
# the            : O     O
# cut            : O     O
# surfaces       : O     O
# of             : O     O
# the            : O     O
# garlic         : B-IN  B-IN
# making         : O     O
# sure           : O     O
# theyre         : O     O
# coated         : O     O
# in             : O     O
# oil            : B-IN  B-IN
# cover          : O     O
# the            : O     O
# baking         : B-CO  B-CO
# dish           : I-CO  I-CO
# tightly        : O     O
# with           : O     O
# a              : O     O
# lid            : O     O
# or             : O     O
# foil           : B-IN  O
# and            : O     O
# transfer       : O     O
# to             : O     O
# the            : O     O
# oven           : B-CO  B-CO
# roast          : O     O
# for            : O     O
# 30             : B-TI  B-TI
# minutes        : I-TI  I-TI
# then           : O     O
# check          : O     O
# the            : O     O
# garlic         : B-IN  B-IN
# add            : O     O
# more           : O     O
# time           : O     O
# in             : O     O
# the            : O     O
# oven           : B-CO  B-CO
# 10-15          : B-TI  B-TI
# minutes        : I-TI  I-TI
# at             : O     O
# a              : O     O
# time           : O     O
# until          : O     O
# the            : O     O
# garlic         : B-IN  O
# is             : O     O
# deeply         : O     O
# golden         : O     O
# brown          : O     O
# total          : O     O
# roasting       : O     O
# time           : O     O
# will           : O     O
# vary           : O     O
# with           : O     O
# the            : O     O
# size           : O     O
# and            : O     O
# number         : O     O
# of             : O     O
# garlic         : B-IN  B-IN
# heads          : O     O
# youre          : O     O
# roasting       : O     O
# as             : O     O
# well           : O     O
# as             : O     O
# the            : O     O
# type           : O     O
# of             : O     O
# dish           : O     B-CO
# youre          : O     O
# roasting       : O     O
# in             : O     O
# let            : O     O
# the            : O     O
# garlic         : B-IN  B-IN
# cool           : O     O
# once           : O     O
# cool           : O     O
# enough         : O     O
# to             : O     O
# handle         : O     O
# squeeze        : O     O
# the            : O     O
# soft           : O     O
# roasted        : O     O
# garlic         : B-IN  O
# out            : O     O
# of             : O     O
# the            : O     O
# heads          : O     O
# use            : O     O
# immediately    : O     O
# store          : O     O
# in             : O     O
# the            : O     O
# refrigerator   : B-CO  B-CO
# or             : O     O
# freezer        : B-CO  O
# for            : O     O
# later          : O     O
# use            : O     O
# 1/1 [==============================] - 0s 178ms/step
# Word||True||Pred
# ==============================
# if             : O     O
# your           : O     O
# graham         : B-IN  O
# crackers       : I-IN  O
# arent          : O     O
# already        : O     O
# in             : O     O
# crumb          : O     O
# form           : O     O
# use            : O     O
# a              : O     O
# food           : B-CO  B-CO
# processor      : I-CO  I-CO
# to             : O     O
# blitz          : O     O
# them           : O     O
# into           : O     O
# a              : O     O
# fine           : O     B-CO
# crumb          : O     O
# place          : O     O
# the            : O     O
# butter         : B-IN  B-IN
# and            : O     O
# 1              : B-ME  B-ME
# cup            : I-ME  I-ME
# of             : O     O
# peanut         : B-IN  B-IN
# butter         : I-IN  I-IN
# in             : O     O
# a              : O     O
# bowl           : B-CO  B-CO
# microwave      : B-CO  I-CO
# and            : O     O
# stir           : O     O
# in             : O     O
# 30-second      : B-TI  O
# intervals      : O     O
# just           : O     O
# until          : O     O
# theyre         : O     O
# warm           : O     O
# enough         : O     O
# to             : O     O
# melt           : O     O
# together       : O     O
# stir           : O     O
# until          : O     O
# evenly         : O     O
# combined       : O     O
# reserve        : O     O
# the            : O     O
# last           : O     O
# 2              : B-ME  B-ME
# Tbsp           : I-ME  I-ME
# peanut         : B-IN  B-IN
# butter         : I-IN  I-IN
# for            : O     O
# later          : O     O
# add            : O     O
# the            : O     O
# powdered       : B-IN  B-IN
# sugar          : I-IN  I-IN
# and            : O     O
# graham         : B-IN  O
# cracker        : I-IN  O
# crumbs         : O     O
# to             : O     O
# the            : O     O
# melted         : O     O
# peanut         : B-IN  B-IN
# butter         : I-IN  I-IN
# mixture        : O     O
# and            : O     O
# stir           : O     O
# until          : O     O
# evenly         : O     O
# combined       : O     O
# line           : O     O
# an             : O     O
# 8×8-inch       : B-ME  B-CO
# baking         : B-IN  B-CO
# dish           : I-IN  I-CO
# with           : O     O
# parchment      : B-IN  B-IN
# paper          : I-IN  I-IN
# making         : O     O
# sure           : O     O
# some           : O     O
# of             : O     O
# the            : O     O
# paper          : O     B-IN
# overhangs      : O     O
# on             : O     O
# the            : O     O
# sides          : O     O
# so             : O     O
# you            : O     O
# can            : O     O
# lift           : O     O
# the            : O     O
# bars           : O     O
# out            : O     O
# of             : O     O
# the            : O     O
# dish           : B-CO  B-CO
# later          : O     O
# press          : O     O
# the            : O     O
# peanut         : B-IN  B-IN
# butter         : I-IN  I-IN
# mixture        : O     O
# into           : O     O
# the            : O     O
# bottom         : O     O
# in             : O     O
# an             : O     O
# even           : O     O
# layer          : O     O
# add            : O     O
# the            : O     O
# chocolate      : B-IN  B-IN
# chips          : I-IN  I-IN
# and            : O     O
# the            : O     O
# last           : O     O
# 2              : B-ME  B-ME
# Tbsp           : I-ME  I-ME
# peanut         : B-IN  B-IN
# butter         : I-IN  B-IN
# to             : O     O
# a              : O     O
# bowl           : B-CO  B-CO
# microwave      : O     I-CO
# for            : O     O
# 30             : B-TI  B-TI
# seconds        : I-TI  I-TI
# then           : O     O
# stir           : O     O
# continue       : O     O
# to             : O     O
# microwave      : B-IN  B-CO
# and            : O     O
# stir           : O     O
# in             : O     O
# 15             : B-TI  B-CO
# second         : I-TI  O
# increments     : O     O
# until          : O     O
# the            : O     O
# chocolate      : B-IN  B-IN
# is             : O     O
# fully          : O     O
# melted         : O     O
# and            : O     O
# smooth         : O     O
# pour           : O     O
# the            : O     O
# melted         : O     O
# chocolate      : B-IN  B-IN
# over           : O     O
# the            : O     O
# peanut         : B-IN  B-IN
# butter         : I-IN  I-IN
# base           : O     O
# in             : O     O
# the            : O     O
# baking         : B-CO  B-CO
# dish           : I-CO  I-CO
# and            : O     O
# spread         : O     O
# it             : O     O
# smooth         : O     O
# add            : O     O
# the            : O     O
# mini           : O     O
# pretzels       : B-IN  O
# on             : O     O
# top            : O     O
# in             : O     O
# even           : O     O
# rows           : O     O
# i              : O     O
# did            : O     O
# five           : O     O
# rows           : O     O
# of             : O     O
# five           : O     O
# across         : O     O
# refrigerate    : O     O
# the            : O     O
# peanut         : B-IN  B-IN
# butter         : I-IN  I-IN
# bars           : O     O
# for            : O     O
# two            : B-TI  B-TI
# hours          : I-TI  I-TI
# or             : O     O
# until          : O     O
# completely     : O     O
# set            : O     O
# once           : O     O
# set            : O     O
# lift           : O     O
# the            : O     O
# bars           : O     O
# out            : O     O
# of             : O     O
# the            : O     O
# dish           : B-CO  B-CO
# using          : O     O
# the            : O     O
# parchment      : B-IN  B-IN
# paper          : I-IN  I-IN
# use            : O     O
# a              : O     O
# sharp          : O     O
# knife          : B-CO  B-CO
# to             : O     O
# cut            : O     O
# them           : O     O
# into           : O     O
# squares        : O     O
# between        : O     O
# the            : O     O
# pretzels       : B-IN  O
# enjoy          : O     O
# immediately    : O     O
# refrigerate    : O     O
# for            : O     O
# later          : O     O
# or             : O     O
# freeze         : O     O
# for            : O     O
# long           : O     O
# term           : O     O
# storage        : O     O
# 1/1 [==============================] - 0s 191ms/step
# Word||True||Pred
# ==============================
# preheat        : O     O
# the            : O     O
# oven           : O     B-CO
# to             : O     O
# 400ºf          : B-TE  B-TE
# wash           : O     O
# the            : O     O
# Brussels       : B-IN  B-IN
# sprouts        : I-IN  I-IN
# and            : O     O
# cut            : O     O
# them           : O     O
# in             : O     O
# half           : O     O
# peel           : O     O
# and            : O     O
# dice           : O     O
# the            : O     O
# sweet          : B-IN  B-IN
# potatoes       : I-IN  I-IN
# into           : O     O
# ¾-inch         : B-ME  I-ME
# cubes          : O     I-IN
# line           : O     O
# a              : O     O
# large          : O     O
# baking         : B-CO  B-CO
# sheet          : I-CO  I-CO
# with           : O     O
# parchment      : B-IN  B-IN
# then           : O     O
# add            : O     O
# the            : O     O
# Brussels       : B-IN  B-IN
# sprouts        : I-IN  I-IN
# to             : O     O
# one            : O     O
# side           : O     O
# and            : O     O
# the            : O     O
# sweet          : B-IN  B-IN
# potatoes       : I-IN  I-IN
# to             : O     O
# the            : O     O
# other          : O     O
# side           : O     O
# drizzle        : O     O
# olive          : B-IN  O
# oil            : I-IN  I-IN
# over           : O     O
# the            : O     O
# vegetables     : O     B-IN
# and            : O     O
# add            : O     O
# a              : B-ME  B-ME
# pinch          : I-ME  I-ME
# of             : O     O
# salt           : B-IN  B-IN
# and            : O     O
# pepper         : B-IN  B-IN
# toss           : O     O
# until          : O     O
# the            : O     O
# vegetables     : O     B-IN
# are            : O     O
# coated         : O     O
# in             : O     O
# oil            : B-IN  B-IN
# transfer       : O     O
# the            : O     O
# vegetables     : O     B-IN
# to             : O     O
# the            : O     O
# oven           : B-CO  B-CO
# and            : O     O
# roast          : O     O
# for            : O     O
# 20             : B-TI  B-TI
# minutes        : I-TI  I-TI
# give           : O     O
# the            : O     O
# vegetables     : O     B-IN
# a              : O     O
# good           : O     O
# stir           : O     O
# keeping        : O     O
# them           : O     O
# each           : O     O
# on             : O     O
# their          : O     O
# own            : O     O
# side           : O     O
# then           : O     O
# roast          : O     O
# for            : O     O
# an             : O     O
# additional     : O     O
# 10             : B-TI  B-TI
# minutes        : I-TI  I-TI
# or             : O     O
# until          : O     O
# the            : O     O
# Brussels       : B-IN  B-IN
# sprouts        : I-IN  I-IN
# are            : O     O
# browned        : O     O
# and            : O     O
# the            : O     O
# sweet          : B-IN  B-IN
# potatoes       : I-IN  I-IN
# are            : O     O
# tender         : O     O
# while          : O     O
# the            : O     O
# vegetables     : O     B-IN
# are            : O     O
# roasting       : O     O
# make           : O     O
# the            : O     O
# maple          : O     B-IN
# dijon          : O     I-IN
# vinaigrette    : O     I-IN
# whisk          : O     O
# together       : O     O
# the            : O     O
# maple          : B-IN  B-IN
# syrup          : I-IN  I-IN
# apple          : B-IN  B-IN
# cider          : I-IN  I-IN
# vinegar        : B-IN  B-IN
# Dijon          : B-IN  B-IN
# mustard        : I-IN  I-IN
# olive          : B-IN  B-IN
# oil            : I-IN  I-IN
# garlic         : B-IN  B-IN
# powder         : I-IN  I-IN
# salt           : B-IN  B-IN
# and            : O     O
# pepper         : B-IN  B-IN
# add            : O     O
# the            : O     O
# chopped        : O     O
# pecans         : B-IN  B-IN
# to             : O     O
# a              : O     O
# skillet        : B-CO  B-CO
# and            : O     O
# place          : O     O
# over           : O     O
# medium         : O     O
# heat           : O     O
# stir           : O     O
# and            : O     O
# cook           : O     O
# the            : O     O
# pecans         : B-IN  B-IN
# for            : O     O
# 2-3            : B-TI  B-TI
# minutes        : I-TI  I-TI
# or             : O     O
# just           : O     O
# until          : O     O
# they           : O     O
# begin          : O     O
# to             : O     O
# smell          : O     O
# toasty         : O     O
# then           : O     O
# remove         : O     O
# them           : O     O
# from           : O     O
# the            : O     O
# heat           : O     O
# once           : O     O
# the            : O     O
# vegetables     : O     B-IN
# have           : O     O
# finished       : O     O
# roasting       : O     O
# transfer       : O     O
# them           : O     O
# to             : O     O
# a              : O     O
# large          : O     O
# bowl           : B-CO  B-CO
# and            : O     O
# add            : O     O
# the            : O     O
# toasted        : O     O
# nuts           : B-IN  B-CO
# drizzle        : O     B-CO
# with           : O     O
# half           : O     O
# of             : O     O
# the            : O     O
# vinaigrette    : O     B-IN
# and            : O     O
# toss           : O     O
# to             : O     O
# coat           : O     O
# add            : O     O
# more           : O     O
# dressing       : O     O
# to             : O     O
# your           : O     O
# liking         : O     O
# crumble        : O     O
# the            : O     O
# goat           : B-IN  B-IN
# cheese         : I-IN  I-IN
# over           : O     O
# the            : O     O
# salad          : O     O
# just           : O     O
# before         : O     O
# serving        : O     O
# enjoy          : O     O
# 1/1 [==============================] - 0s 184ms/step
# Word||True||Pred
# ==============================
# prepare        : O     O
# the            : O     O
# vegetables     : B-IN  B-IN
# before         : O     O
# hand           : O     B-IN
# so             : O     O
# theyre         : O     O
# ready          : O     O
# to             : O     O
# go             : O     O
# when           : O     O
# needed         : O     O
# mince          : O     O
# the            : O     O
# garlic         : B-IN  B-IN
# grate          : O     O
# the            : O     O
# ginger         : B-IN  B-IN
# dice           : O     O
# the            : O     O
# carrot         : B-IN  B-IN
# and            : O     O
# bell           : B-IN  B-IN
# pepper         : I-IN  I-IN
# slice          : O     O
# the            : O     O
# green          : B-IN  B-IN
# onions         : I-IN  I-IN
# separate       : O     O
# the            : O     O
# green          : O     B-IN
# ends           : O     O
# from           : O     O
# the            : O     O
# white          : O     O
# ends           : O     O
# and            : O     O
# measure        : O     O
# the            : O     O
# frozen         : O     O
# peas           : B-IN  B-IN
# lightly        : O     O
# whisk          : O     O
# the            : O     O
# eggs           : B-IN  B-IN
# in             : O     O
# a              : O     O
# small          : O     O
# bowl           : B-CO  B-CO
# heat           : O     O
# a              : O     O
# large          : O     O
# skillet        : B-CO  B-CO
# over           : O     O
# medium         : O     O
# once           : O     O
# hot            : O     O
# add            : O     O
# 2              : B-ME  B-ME
# Tbsp           : I-ME  I-ME
# of             : O     O
# cooking        : B-IN  B-IN
# oil            : I-IN  I-IN
# and            : O     O
# swirl          : O     O
# to             : O     O
# coat           : O     O
# the            : O     O
# surface        : O     O
# add            : O     O
# the            : O     O
# eggs           : B-IN  B-IN
# and            : O     O
# gently         : O     O
# scramble       : O     O
# until          : O     O
# cooked         : O     O
# through        : O     O
# transfer       : O     O
# the            : O     O
# cooked         : O     O
# eggs           : B-IN  B-IN
# to             : O     O
# a              : O     O
# clean          : O     O
# bowl           : B-CO  B-CO
# or             : O     B-CO
# plate          : B-CO  I-CO
# there          : O     O
# should         : O     O
# be             : O     O
# a              : O     O
# good           : O     O
# amount         : O     O
# of             : O     O
# oil            : B-IN  B-IN
# left           : O     O
# in             : O     O
# the            : O     O
# skillet        : B-CO  B-CO
# turn           : O     O
# the            : O     O
# heat           : O     O
# up             : O     O
# to             : O     O
# medium-high    : O     O
# add            : O     O
# the            : O     O
# diced          : O     O
# carrots        : B-IN  B-IN
# and            : O     O
# stir           : O     O
# and            : O     O
# cook           : O     O
# for            : O     O
# about          : O     O
# two            : B-TI  B-TI
# minutes        : I-TI  I-TI
# next           : O     O
# add            : O     O
# the            : O     O
# bell           : B-IN  B-IN
# pepper         : I-IN  I-IN
# and            : O     O
# the            : O     O
# white          : O     O
# firm           : O     O
# ends           : O     O
# of             : O     O
# the            : O     O
# green          : B-IN  B-IN
# onions         : I-IN  I-IN
# cook           : O     O
# and            : O     O
# stir           : O     O
# for            : O     O
# one            : B-TI  B-TI
# minute         : I-TI  I-TI
# more           : O     O
# finally        : O     O
# add            : O     O
# the            : O     O
# frozen         : O     O
# peas           : B-IN  B-IN
# and            : O     O
# stir           : O     O
# and            : O     O
# cook           : O     O
# until          : O     O
# heated         : O     O
# through        : O     O
# transfer       : O     O
# the            : O     O
# vegetables     : B-IN  B-IN
# to             : O     O
# a              : O     O
# clean          : O     O
# bowl           : B-CO  B-CO
# or             : O     O
# plate          : O     B-CO
# add            : O     O
# the            : O     O
# remaining      : O     O
# 1              : B-ME  B-ME
# Tbsp           : I-ME  I-ME
# cooking        : B-IN  B-IN
# oil            : I-IN  I-IN
# to             : O     O
# the            : O     O
# skillet        : B-CO  B-CO
# and            : O     O
# swirl          : O     O
# to             : O     O
# coat           : O     O
# the            : O     O
# surface        : O     O
# add            : O     O
# the            : O     O
# garlic         : B-IN  B-IN
# ginger         : B-IN  B-IN
# and            : O     O
# cooked         : O     O
# and            : O     O
# cooled         : O     O
# rice           : B-IN  B-IN
# to             : O     O
# the            : O     O
# skillet        : B-CO  B-CO
# stir           : O     O
# and            : O     O
# cook           : O     O
# for            : O     O
# about          : O     O
# 2              : B-TI  B-TI
# minutes        : I-TI  I-TI
# or             : O     O
# until          : O     O
# the            : O     O
# rice           : B-IN  B-IN
# is             : O     O
# heated         : O     O
# through        : O     O
# pour           : O     O
# the            : O     O
# soy            : B-IN  B-IN
# sauce          : I-IN  I-IN
# and            : O     O
# toasted        : O     O
# sesame         : B-IN  B-IN
# oil            : I-IN  I-IN
# over           : O     O
# the            : O     O
# rice           : B-IN  B-IN
# stir           : O     O
# the            : O     O
# rice           : B-IN  B-IN
# and            : O     O
# sauce          : O     O
# together       : O     O
# until          : O     O
# evenly         : O     O
# combined       : O     O
# turn           : O     O
# the            : O     O
# heat           : O     O
# off            : O     O
# add            : O     O
# the            : O     O
# eggs           : B-IN  B-IN
# and            : O     O
# vegetables     : B-IN  B-IN
# back           : O     O
# to             : O     O
# the            : O     O
# skillet        : B-CO  B-CO
# with           : O     O
# the            : O     O
# rice           : B-IN  B-IN
# and            : O     O
# stir           : O     O
# to             : O     O
# combine        : O     O
# allow          : O     O
# the            : O     O
# residual       : O     O
# heat           : O     O
# to             : O     O
# heat           : O     O
# everything     : O     O
# through        : O     O
# top            : O     O
# with           : O     O
# the            : O     O
# remaining      : O     O
# green          : O     O
# ends           : O     O
# of             : O     O
# the            : O     O
# sliced         : O     O
# green          : B-IN  B-IN
# onions         : I-IN  I-IN
# taste          : O     O
# and            : O     O
# adjust         : O     O
# the            : O     O
# soy            : B-IN  B-IN
# sauce          : I-IN  I-IN
# or             : O     O
# sesame         : B-IN  B-IN
# oil            : I-IN  I-IN
# to             : O     O
# your           : O     O
# liking         : O     O
# 1/1 [==============================] - 0s 164ms/step
# Word||True||Pred
# ==============================
# dice           : O     O
# the            : O     O
# onion          : B-IN  B-IN
# and            : O     O
# chop           : O     O
# the            : O     O
# cabbage        : B-IN  B-IN
# into           : O     O
# ½-inch         : B-ME  B-ME
# pieces         : O     O
# add            : O     O
# the            : O     O
# onion          : B-IN  B-IN
# and            : O     O
# cooking        : B-IN  O
# oil            : I-IN  I-IN
# to             : O     O
# a              : O     O
# large          : O     O
# skillet        : B-CO  B-CO
# and            : O     O
# sauté          : O     O
# over           : O     O
# medium         : O     O
# heat           : O     O
# until          : O     O
# the            : O     O
# onions         : B-IN  B-IN
# are            : O     O
# soft           : O     O
# add            : O     O
# the            : O     O
# ground         : B-IN  O
# beef           : I-IN  I-IN
# and            : O     O
# steak          : B-IN  B-IN
# seasoning      : I-IN  I-IN
# to             : O     O
# the            : O     O
# skillet        : B-CO  B-CO
# and            : O     O
# continue       : O     O
# to             : O     O
# sauté          : O     O
# until          : O     O
# the            : O     O
# beef           : B-IN  B-IN
# is             : O     O
# fully          : O     O
# cooked         : O     O
# if             : O     O
# using          : O     O
# a              : O     O
# higher         : O     O
# fat            : O     O
# content        : O     O
# beef           : O     B-IN
# drain          : O     O
# the            : O     O
# excess         : O     O
# fat            : O     O
# from           : O     O
# the            : O     O
# skillet        : B-CO  B-CO
# add            : O     O
# the            : O     O
# chopped        : O     O
# cabbage        : B-IN  B-IN
# and            : O     O
# water          : B-IN  B-IN
# to             : O     O
# the            : O     O
# skillet        : B-CO  B-CO
# continue       : O     O
# to             : O     O
# sauté          : O     O
# until          : O     O
# the            : O     O
# cabbage        : B-IN  B-IN
# has            : O     O
# softened       : O     O
# to             : O     O
# your           : O     O
# desired        : O     O
# level          : O     O
# of             : O     O
# tenderness     : O     O
# add            : O     O
# the            : O     O
# cooked         : O     O
# rice           : B-IN  B-IN
# and            : O     O
# butter         : B-IN  B-IN
# to             : O     O
# the            : O     O
# skillet        : B-CO  B-CO
# fold           : O     O
# the            : O     O
# rice           : B-IN  B-IN
# and            : O     O
# butter         : B-IN  B-IN
# into           : O     O
# the            : O     O
# beef           : B-IN  B-IN
# and            : O     O
# cabbage        : B-IN  B-IN
# until          : O     O
# the            : O     O
# butter         : B-IN  B-IN
# has            : O     O
# melted         : O     O
# everything     : O     O
# is             : O     O
# evenly         : O     O
# combined       : O     O
# and            : O     O
# the            : O     O
# rice           : B-IN  B-IN
# is             : O     O
# heated         : O     O
# through        : O     O
# finally        : O     O
# season         : O     O
# the            : O     O
# skillet        : B-CO  B-CO
# with           : O     O
# soy            : B-IN  B-IN
# sauce          : I-IN  I-IN
# to             : O     O
# taste          : O     O
# start          : O     O
# with           : O     O
# 1              : B-ME  B-ME
# tsp            : I-ME  I-ME
# and            : O     O
# add            : O     O
# more           : O     O
# to             : O     O
# your           : O     O
# liking         : O     O
# i              : O     O
# added          : O     O
# ½              : B-ME  O
# Tbsp           : I-ME  I-ME
# or             : O     O
# 15             : B-ME  B-ME
# tsp            : I-ME  I-ME
# serve          : O     O
# hot            : O     O
# and            : O     O
# enjoy          : O     O
# 1/1 [==============================] - 0s 173ms/step
# Word||True||Pred
# ==============================
# preheat        : O     O
# the            : O     O
# oven           : B-CO  B-CO
# to             : O     O
# 400ºf          : B-TE  B-TE
# clean          : O     O
# any            : O     O
# dirt           : O     O
# or             : O     O
# debris         : O     O
# from           : O     O
# the            : O     O
# mushrooms      : B-IN  B-IN
# then           : O     O
# slice          : O     O
# any            : O     O
# large          : O     O
# mushrooms      : B-IN  B-IN
# in             : O     O
# half           : O     O
# you            : O     O
# can            : O     O
# leave          : O     O
# them           : O     O
# whole          : O     O
# if             : O     O
# they           : O     O
# are            : O     O
# small          : O     O
# mince          : O     O
# the            : O     O
# garlic         : B-IN  B-IN
# in             : O     O
# a              : O     O
# small          : O     O
# bowl           : B-CO  B-CO
# combine        : O     O
# the            : O     O
# olive          : B-IN  B-IN
# oil            : I-IN  I-IN
# balsamic       : B-IN  B-IN
# vinegar        : I-IN  I-IN
# brown          : B-IN  B-IN
# sugar          : I-IN  I-IN
# soy            : B-IN  B-IN
# sauce          : I-IN  I-IN
# garlic         : B-IN  B-IN
# thyme          : B-IN  B-IN
# and            : O     O
# pepper         : B-IN  B-IN
# place          : O     O
# the            : O     O
# mushrooms      : B-IN  B-IN
# in             : O     O
# a              : O     O
# ceramic        : B-CO  O
# or             : O     O
# glass          : B-CO  B-CO
# baking         : I-CO  B-CO
# dish           : I-CO  I-CO
# choose         : O     O
# a              : O     O
# size           : O     O
# that           : O     O
# keeps          : O     O
# the            : O     O
# mushrooms      : B-IN  B-IN
# close          : O     O
# together       : O     O
# mostly         : O     O
# in             : O     O
# a              : O     O
# single         : O     O
# layer          : O     O
# pour           : O     O
# the            : O     O
# marinade       : O     O
# over           : O     O
# top            : O     O
# and            : O     O
# stir           : O     O
# to             : O     O
# coat           : O     O
# the            : O     O
# mushrooms      : B-IN  B-IN
# roast          : O     O
# the            : O     O
# mushrooms      : B-IN  O
# for            : O     O
# about          : O     O
# 45             : B-TI  B-TI
# ...
# mixture        : O     O
# looks          : O     O
# like           : O     O
# creamy         : O     O
# and            : O     O
# fluffy         : O     O
# add            : O     O
# the            : O     O
# egg            : B-IN  B-IN
# and            : O     O
# vanilla        : B-IN  B-IN
# and            : O     O
# beat           : O     O
# until          : O     O
# incorporated   : O     O
# in             : O     O
# a              : O     O
# separate       : O     O
# bowl           : B-CO  B-CO
# stir           : O     O
# together       : O     O
# the            : O     O
# flour          : B-IN  B-IN
# and            : O     O
# baking         : B-IN  B-IN
# powder         : I-IN  I-IN
# add            : O     O
# half           : O     O
# of             : O     O
# the            : O     O
# flour          : B-IN  B-IN
# mixture        : O     O
# to             : O     O
# the            : O     O
# mixing         : O     O
# bowl           : B-CO  B-CO
# and            : O     O
# beat           : O     O
# over           : O     O
# low            : O     O
# speed          : O     O
# until          : O     O
# it             : O     O
# is             : O     O
# incorporated   : O     O
# add            : O     O
# the            : O     O
# remaining      : O     O
# flour          : B-IN  B-IN
# and            : O     O
# beat           : O     O
# until          : O     O
# a              : O     O
# soft           : O     O
# dough          : O     O
# forms          : O     O
# with           : O     O
# no             : O     O
# loose          : O     O
# flour          : B-IN  B-IN
# on             : O     O
# the            : O     O
# bottom         : O     O
# of             : O     O
# the            : O     O
# bowl           : B-CO  B-CO
# divide         : O     O
# and            : O     O
# shape          : O     O
# the            : O     O
# dough          : O     O
# into           : O     O
# 18             : O     O
# balls          : O     O
# of             : O     O
# dough          : O     O
# place          : O     O
# the            : O     O
# remaining      : O     O
# 2              : B-ME  B-ME
# Tbsp           : I-ME  I-ME
# of             : O     O
# sugar          : B-IN  B-IN
# in             : O     O
# a              : O     O
# small          : O     O
# bowl           : B-CO  B-CO
# and            : O     O
# roll           : O     O
# each           : O     O
# ball           : O     O
# of             : O     O
# dough          : O     O
# in             : O     O
# the            : O     O
# sugar          : B-IN  B-IN
# to             : O     O
# coat           : O     O
# place          : O     O
# the            : O     O
# cookies        : O     O
# on             : O     O
# a              : O     O
# parchment-lined: O     O
# baking         : B-CO  B-CO
# sheet          : I-CO  I-CO
# bake           : O     O
# the            : O     O
# cookies        : O     O
# for            : O     O
# 8-10           : B-TI  B-TI
# minutes        : I-TI  I-TI
# or             : O     O
# until          : O     O
# they           : O     O
# are            : O     O
# slightly       : O     O
# puffed         : O     O
# a              : O     O
# few            : O     O
# small          : O     O
# cracks         : O     O
# appear         : O     O
# around         : O     O
# the            : O     O
# bottom         : O     O
# edge           : O     O
# and            : O     O
# theyre         : O     O
# just           : O     O
# barely         : O     O
# golden         : O     O
# brown          : O     O
# on             : O     O
# top            : O     O
# remove         : O     O
# the            : O     O
# cookies        : O     O
# from           : O     O
# the            : O     O
# oven           : B-CO  B-CO
# and            : O     O
# immediately    : O     O
# press          : O     O
# a              : O     O
# frozen         : O     O
# chocolate      : B-IN  B-IN
# kiss           : I-IN  O
# into           : O     O
# the            : O     O
# center         : O     O
# of             : O     O
# each           : O     O
# cookie         : O     O
# allow          : O     O
# the            : O     O
# cookies        : O     O
# to             : O     O
# cool           : O     O
# on             : O     O
# the            : O     O
# baking         : B-CO  B-CO
# sheet          : I-CO  I-CO
# for            : O     O
# 5-10           : B-TI  B-CO
# minutes        : I-TI  I-CO
# then           : O     O
# transfer       : O     O
# to             : O     O
# a              : O     O
# wire           : B-CO  B-CO
# cooling        : I-CO  B-CO
# rack           : I-CO  I-CO
# using          : O     O
# a              : O     O
# spatula        : B-CO  B-CO
# enjoy          : O     O
# warm           : O     O
# or             : O     O
# allow          : O     O
# to             : O     O
# fully          : O     O
# cool           : O     O
# before         : O     O
# packing        : O     O
# and            : O     O
# storing        : O     O
# 1/1 [==============================] - 0s 170ms/step
# Word||True||Pred
# ==============================
# prepare        : O     O
# the            : O     O
# marinade       : O     O
# first          : O     O
# stir           : O     O
# together       : O     O
# the            : O     O
# soy            : B-IN  B-IN
# sauce          : I-IN  I-IN
# brown          : B-IN  I-IN
# sugar          : I-IN  I-IN
# water          : B-IN  B-IN
# garlic         : B-IN  B-IN
# ginger         : B-IN  B-IN
# and            : O     O
# 1              : B-ME  B-ME
# Tbsp           : I-ME  I-ME
# of             : O     O
# the            : O     O
# cooking        : B-IN  O
# oil            : I-IN  I-IN
# in             : O     O
# a              : O     O
# bowl           : B-CO  B-CO
# place          : O     O
# the            : O     O
# chicken        : B-IN  B-IN
# in             : O     O
# a              : O     O
# shallow        : O     O
# bowl           : B-CO  B-CO
# or             : O     O
# dish           : B-CO  B-CO
# then           : O     O
# pour           : O     O
# the            : O     O
# marinade       : O     O
# over           : O     O
# top            : O     O
# turn           : O     O
# the            : O     O
# chicken        : B-IN  B-IN
# a              : O     O
# couple         : O     O
# of             : O     O
# times          : O     O
# to             : O     O
# make           : O     O
# sure           : O     O
# its            : O     O
# well           : O     O
# coated         : O     O
# let            : O     O
# the            : O     O
# chicken        : B-IN  B-IN
# marinate       : O     O
# for            : O     O
# 30             : B-TI  B-TI
# minutes        : I-TI  I-TI
# to             : O     O
# one            : B-TI  O
# day            : I-TI  O
# refrigerated   : O     O
# turning        : O     O
# the            : O     O
# chicken        : B-IN  B-IN
# occasionally   : O     O
# as             : O     O
# it             : O     O
# marinates      : O     O
# when           : O     O
# ready          : O     O
# to             : O     O
# cook           : O     O
# the            : O     O
# chicken        : B-IN  B-IN
# heat           : O     O
# the            : O     O
# remaining      : O     O
# 1              : B-ME  B-ME
# Tbsp           : I-ME  I-ME
# cooking        : B-IN  B-IN
# oil            : I-IN  I-IN
# in             : O     O
# a              : O     O
# large          : O     O
# skillet        : B-CO  B-CO
# over           : O     O
# medium         : O     O
# heat           : O     O
# once           : O     O
# hot            : O     O
# add            : O     O
# the            : O     O
# chicken        : B-IN  B-IN
# discarding     : O     O
# the            : O     O
# remaining      : O     O
# used           : O     O
# marinade       : O     O
# cook           : O     O
# the            : O     O
# chicken        : B-IN  B-IN
# for            : O     O
# about          : O     O
# 5-7            : B-TI  B-TI
# minutes        : I-TI  I-TI
# on             : O     O
# each           : O     O
# side           : O     O
# or             : O     O
# until          : O     O
# cooked         : O     O
# through        : O     O
# and            : O     O
# the            : O     O
# liquid         : O     O
# in             : O     O
# the            : O     O
# skillet        : B-CO  B-CO
# has            : O     O
# reduced        : O     O
# to             : O     O
# a              : O     O
# light          : O     O
# coating        : O     O
# of             : O     O
# glaze          : O     O
# on             : O     O
# the            : O     O
# chicken        : B-IN  B-IN
# transfer       : O     O
# the            : O     O
# chicken        : B-IN  B-IN
# to             : O     O
# a              : O     O
# cutting        : B-CO  B-CO
# board          : I-CO  I-CO
# and            : O     O
# let            : O     O
# it             : O     O
# rest           : O     O
# for            : O     O
# about          : O     O
# 5              : B-TI  B-TI
# minutes        : I-TI  I-TI
# before         : O     O
# slicing        : O     O
# and            : O     O
# serving        : O     O
# 1/1 [==============================] - 0s 178ms/step
# Word||True||Pred
# ==============================
# preheat        : O     O
# the            : O     O
# oven           : B-CO  B-CO
# to             : O     O
# 350ºf          : B-TE  B-TE
# cut            : O     O
# the            : O     O
# bacon          : B-IN  B-IN
# into           : O     O
# 1-inch         : B-ME  B-ME
# pieces         : O     O
# and            : O     O
# cook           : O     O
# in             : O     O
# a              : O     O
# skillet        : B-CO  B-CO
# over           : O     O
# medium         : O     O
# heat           : O     O
# until          : O     O
# brown          : O     O
# and            : O     O
# crispy         : O     O
# drain          : O     O
# off            : O     O
# all            : O     O
# but            : O     O
# 1-2            : B-ME  B-ME
# Tbsp           : I-ME  I-ME
# of             : O     O
# the            : O     O
# bacon          : B-IN  O
# fat            : I-IN  O
# drain          : O     O
# the            : O     O
# canned         : O     O
# beans          : B-IN  I-IN
# well           : O     O
# then           : O     O
# add            : O     O
# them           : O     O
# to             : O     O
# the            : O     O
# skillet        : B-CO  B-CO
# and            : O     O
# stir           : O     O
# to             : O     O
# combine        : O     O
# with           : O     O
# the            : O     O
# bacon          : B-IN  B-IN
# add            : O     O
# the            : O     O
# remaining      : O     O
# ingredients    : O     O
# tomato         : B-IN  B-IN
# sauce          : I-IN  I-IN
# tomato         : B-IN  I-IN
# paste          : I-IN  I-IN
# apple          : B-IN  B-IN
# cider          : I-IN  I-IN
# vinegar        : I-IN  B-IN
# brown          : B-IN  B-IN
# sugar          : I-IN  I-IN
# molasses       : B-IN  B-IN
# dijon          : B-IN  B-IN
# Worcestershire : B-IN  B-IN
# sauce          : I-IN  I-IN
# smoked         : O     O
# paprika        : B-IN  B-IN
# garlic         : B-IN  B-IN
# powder         : I-IN  I-IN
# onion          : B-IN  B-IN
# powder         : I-IN  I-IN
# cayenne        : B-IN  B-IN
# and            : O     O
# black          : B-IN  B-IN
# pepper         : I-IN  I-IN
# stir           : O     O
# until          : O     O
# everything     : O     O
# is             : O     O
# very           : O     O
# well           : O     O
# combined       : O     O
# bake           : O     O
# the            : O     O
# beans          : B-IN  B-IN
# for            : O     O
# 60-75          : B-TI  O
# minutes        : I-TI  I-TI
# stirring       : O     O
# once           : O     O
# at             : O     O
# 30             : B-TI  B-TI
# minutes        : I-TI  I-TI
# and            : O     O
# again          : O     O
# at             : O     O
# 60             : B-TI  B-TI
# minutes        : I-TI  I-TI
# if             : O     O
# the            : O     O
# sauce          : O     O
# is             : O     O
# thick          : O     O
# at             : O     O
# 60             : B-TI  B-TI
# minutes        : I-TI  O
# its            : O     O
# done           : O     O
# if             : O     O
# its            : O     O
# still          : O     O
# a              : O     O
# bit            : O     O
# runny          : O     O
# bake           : O     O
# 10-15          : B-TI  O
# minutes        : I-TI  O
# longer         : O     O
# serve          : O     O
# hot            : O     O
# with           : O     O
# your           : O     O
# other          : O     O
# favorite       : O     O
# comfort        : O     O
# foods          : O     O
# 1/1 [==============================] - 0s 173ms/step
# Word||True||Pred
# ==============================
# preheat        : O     O
# the            : O     O
# oven           : B-CO  B-CO
# to             : O     O
# 350ºf          : B-TE  B-TE
# add            : O     O
# all            : O     O
# of             : O     O
# the            : O     O
# ingredients    : O     O
# to             : O     O
# a              : O     O
# bowl           : B-CO  B-CO
# and            : O     O
# stir           : O     O
# until          : O     O
# it             : O     O
# forms          : O     O
# a              : O     O
# cohesive       : O     O
# dough          : O     O
# it             : O     O
# should         : O     O
# be             : O     O
# firm           : O     O
# enough         : O     O
# to             : O     O
# pull           : O     O
# away           : O     O
# from           : O     O
# the            : O     O
# sides          : O     O
# of             : O     O
# the            : O     O
# bowl           : B-CO  B-CO
# if             : O     O
# the            : O     O
# dough          : O     O
# is             : O     O
# still          : O     O
# too            : O     O
# soft           : O     O
# add            : O     O
# a              : B-ME  O
# tablespoon     : I-ME  I-ME
# or             : I-ME  O
# two            : I-ME  O
# more           : O     O
# of             : O     O
# powdered       : B-IN  O
# sugar          : I-IN  I-IN
# to             : O     O
# further        : O     O
# firm           : O     O
# up             : O     O
# the            : O     O
# dough          : O     O
# divide         : O     O
# the            : O     O
# cookie         : O     O
# dough          : O     O
# into           : O     O
# twelve         : O     O
# pieces         : O     O
# roll           : O     O
# each           : O     O
# piece          : O     O
# into           : O     O
# a              : O     O
# ball           : O     O
# then           : O     O
# flatten        : O     O
# it             : O     O
# slightly       : O     O
# place          : O     O
# the            : O     O
# cookies        : O     O
# on             : O     O
# a              : O     O
# parchment-lined: O     O
# baking         : B-CO  B-CO
# sheet          : I-CO  I-CO
# and            : O     O
# then           : O     O
# use            : O     O
# a              : O     O
# fork           : B-CO  B-CO
# to             : O     O
# create         : O     O
# a              : O     O
# corss          : O     O
# hatch          : O     O
# pattern        : O     O
# on             : O     O
# the            : O     O
# top            : O     O
# of             : O     O
# the            : O     O
# cookie         : O     O
# bake           : O     O
# the            : O     O
# cookies        : O     O
# for            : O     O
# 12             : B-TI  B-TI
# minutes        : I-TI  I-TI
# in             : O     O
# the            : O     O
# preheated      : O     O
# oven           : B-IN  B-CO
# after          : O     O
# baking         : O     B-CO
# allow          : O     O
# them           : O     O
# to             : O     O
# cool           : O     O
# for            : O     O
# about          : O     O
# five           : B-TI  B-TI
# minutes        : I-TI  I-TI
# on             : O     O
# the            : O     O
# baking         : B-CO  B-CO
# sheet          : I-CO  I-CO
# or             : O     O
# until          : O     O
# theyre         : O     O
# firm           : O     O
# enough         : O     O
# to             : O     O
# lift           : O     O
# with           : O     O
# a              : O     O
# spatula        : B-CO  B-CO
# transfer       : O     O
# the            : O     O
# cookies        : O     O
# to             : O     O
# a              : O     O
# wire           : B-CO  B-CO
# rack           : I-CO  I-CO
# to             : O     O
# cool           : O     O
# completely     : O     O
# then           : O     O
# serve          : O     O
# and            : O     O
# enjoy          : O     O

# %% [markdown]
# Combine Values for the different classes

# %%
metrics_dict = {}
for tag, metrics in confusion_matrix_dict.items():
  # Get the string after the second letter
  label = tag[2:]
  # 'O' will have a value of '' after applying the string indexing above
  if label == "":
    metrics_dict['O'] = metrics
  # Initialize the key value pair if it does not exist in metrics_dict
  elif label not in metrics_dict.keys():
    metrics_dict[label] = metrics
  else:
    # Combine the different labels values
    for metric, value in metrics.items():
      metrics_dict[label][metric] += value

# %%
machine_learning_metrics = ["Precision", "Recall", "f1_score"]
NER_metrics = {}
for tag, metrics in metrics_dict.items():
  for metric, value in metrics.items():
    tp = metrics_dict[tag]["true_positive"]
    fp = metrics_dict[tag]["false_positive"]
    fn = metrics_dict[tag]["false_negative"]
    # Compute for the model's precision, recall, and f1_score
    precision = round(tp/(tp+fp), 2)
    recall = round(tp/(tp+fn), 2)
    f1_score = round((2*(precision*recall))/(precision+recall), 2)
  # Create a dictionary that contains each performance metric for each tag in the trained model
  NER_metrics[tag] = {"Precision": precision, "Recall": recall, "F1_Score": f1_score}

# %%
print(json.dumps(NER_metrics,sort_keys=True, indent=4))
# Out:
# {
#     "CO": {
#         "F1_Score": 0.86,
#         "Precision": 0.84,
#         "Recall": 0.89
#     },
#     "IN": {
#         "F1_Score": 0.88,
#         "Precision": 0.91,
#         "Recall": 0.85
#     },
#     "ME": {
#         "F1_Score": 0.92,
#         "Precision": 0.94,
#         "Recall": 0.9
#     },
#     "O": {
#         "F1_Score": 0.97,
#         "Precision": 0.97,
#         "Recall": 0.98
#     },
#     "TE": {
#         "F1_Score": 0.88,
#         "Precision": 1.0,
#         "Recall": 0.78
#     },
#     "TI": {
#         "F1_Score": 0.88,
#         "Precision": 0.92,
#         "Recall": 0.85
#     }
# }

# %% [markdown]
# References:
#
# 1. https://www.depends-on-the-definition.com/sequence-tagging-lstm-crf/
#
# 2. https://www.kaggle.com/code/naseralqaydeh/named-entity-recognition-ner-with-tensorflow/notebook
